# %% [markdown]
# # Project 4: Exploratory Data Analysis (EDA)
#
# ## 45-Day Summer Training
# ### LinuxWorld Informatics Pvt. Ltd.
#
# **Name:** Payal Sharma
#
# ### Objective
# To explore and understand a dataset by analyzing its structure, summary statistics, distributions, and relationships before applying Machine Learning techniques.

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#    Student_ID   Name  Age Course  Marks  Attendance
# 0         101  Payal   20    CSE     85          92
# 1         102   Aman   21    CSE     90          95
# 2         103   Riya   20     IT     78          85
# 3         104  Rahul   22    CSE     88          90
# 4         105  Sneha   21    ECE     95          98
# 5         106  Karan   23     IT     76          80
# 6         107  Priya   20    CSE     82          89
# 7         108   Neha   22    ECE     91          96
# 8         109  Rohit   21     IT     80          84
# 9         110  Ankit   20    CSE     87          91

# %% [markdown]
# ## Display First Five Records

# %%
df.head()
# Out:
#    Student_ID   Name  Age Course  Marks  Attendance
# 0         101  Payal   20    CSE     85          92
# 1         102   Aman   21    CSE     90          95
# 2         103   Riya   20     IT     78          85
# 3         104  Rahul   22    CSE     88          90
# 4         105  Sneha   21    ECE     95          98

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Course      10 non-null     str
#  4   Marks       10 non-null     int64
#  5   Attendance  10 non-null     int64
# dtypes: int64(4), str(2)
# memory usage: 612.0 bytes

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#        Student_ID        Age      Marks  Attendance
# count    10.00000  10.000000  10.000000   10.000000
# mean    105.50000  21.000000  85.200000   90.000000
# std       3.02765   1.054093   6.124632    5.696002
# min     101.00000  20.000000  76.000000   80.000000
# 25%     103.25000  20.000000  80.500000   86.000000
# 50%     105.50000  21.000000  86.000000   90.500000
# 75%     107.75000  21.750000  89.500000   94.250000
# max     110.00000  23.000000  95.000000   98.000000

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Course        0
# Marks         0
# Attendance    0
# dtype: int64

# %% [markdown]
# ## Distribution of Student Marks

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Marks"], bins=5)
plt.title("Distribution of Student Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# ## Attendance vs Marks

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Attendance"], df["Marks"])
plt.title("Attendance vs Marks")
plt.xlabel("Attendance")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# ## Key Insights

# %%
print("Average Marks:", df["Marks"].mean())
print("Highest Marks:", df["Marks"].max())
print("Lowest Marks:", df["Marks"].min())

top_student = df.loc[df["Marks"].idxmax()]
print("\nTop Performing Student:")
print(top_student)
# Out:
# Average Marks: 85.2
# Highest Marks: 95
# Lowest Marks: 76
#
# Top Performing Student:
# Student_ID      105
# Name          Sneha
# Age              21
# Course          ECE
# Marks            95
# Attendance       98
# Name: 4, dtype: object

# %% [markdown]
# ## Conclusion
#
# Exploratory Data Analysis helped in understanding the dataset by examining its structure, generating statistical summaries, identifying missing values, and visualizing important patterns. These insights provide a strong foundation for building accurate Machine Learning models.
