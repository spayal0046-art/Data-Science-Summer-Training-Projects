# %% [markdown]
# # Project 8: Customer Segmentation
#
# ## 45-Day Summer Training
# ### LinuxWorld Informatics Pvt. Ltd.
#
# **Name:** Payal Sharma
#
# ### Objective
#
# To discover hidden customer patterns, segment customers into different groups using Machine Learning, create customer profiles, and provide business recommendations.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("customer_data.csv")

df
# Out:
#     Customer_ID  Age  Annual_Income  Spending_Score
# 0           101   22          25000              35
# 1           102   25          30000              40
# 2           103   28          35000              45
# 3           104   32          40000              50
# 4           105   35          45000              55
# 5           106   38          50000              60
# 6           107   42          60000              65
# 7           108   45          70000              70
# 8           109   48          80000              80
# 9           110   52          90000              90
# 10          111   26          28000              38
# 11          112   31          42000              52
# 12          113   36          48000              58
# 13          114   41          65000              72
# 14          115   50          85000              88

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_ID     15 non-null     int64
#  1   Age             15 non-null     int64
#  2   Annual_Income   15 non-null     int64
#  3   Spending_Score  15 non-null     int64
# dtypes: int64(4)
# memory usage: 612.0 bytes

# %% [markdown]
# ## Selecting Features for Clustering

# %%
X = df[["Annual_Income", "Spending_Score"]]

# %% [markdown]
# ## Apply K-Means Clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

df["Cluster"] = kmeans.fit_predict(X)

df.head()
# Out:
#    Customer_ID  Age  Annual_Income  Spending_Score  Cluster
# 0          101   22          25000              35        2
# 1          102   25          30000              40        2
# 2          103   28          35000              45        2
# 3          104   32          40000              50        0
# 4          105   35          45000              55        0

# %% [markdown]
# ## Customer Segments

# %%
df.groupby("Cluster").mean(numeric_only=True)
# Out:
#          Customer_ID        Age  Annual_Income  Spending_Score
# Cluster
# 0         108.714286  36.428571        50000.0       58.857143
# 1         110.500000  48.750000        81250.0       82.000000
# 2         104.250000  25.250000        29500.0       39.500000

# %% [markdown]
# ## Visualize Customer Segments

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df["Annual_Income"],
    df["Spending_Score"],
    c=df["Cluster"]
)

plt.xlabel("Annual Income")

plt.ylabel("Spending Score")

plt.title("Customer Segmentation")

plt.show()

# %% [markdown]
# ## Business Recommendations

# %%
print("Cluster 0 : Budget-conscious customers")
print("Recommendation : Provide discounts and promotional offers.\n")

print("Cluster 1 : Premium customers")
print("Recommendation : Offer loyalty rewards and premium memberships.\n")

print("Cluster 2 : Moderate customers")
print("Recommendation : Recommend personalized products and targeted marketing.")
# Out:
# Cluster 0 : Budget-conscious customers
# Recommendation : Provide discounts and promotional offers.
#
# Cluster 1 : Premium customers
# Recommendation : Offer loyalty rewards and premium memberships.
#
# Cluster 2 : Moderate customers
# Recommendation : Recommend personalized products and targeted marketing.

# %% [markdown]
# ## Conclusion
#
# Using K-Means clustering, customers were grouped into meaningful segments based on their annual income and spending behavior. These customer profiles help businesses design personalized marketing strategies and improve customer satisfaction.
