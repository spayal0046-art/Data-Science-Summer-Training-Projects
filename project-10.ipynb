# %% [markdown]
# # Project 10: End-to-End ML Workflow
#
# ## 45-Day Summer Training
# ### LinuxWorld Informatics Pvt. Ltd.
#
# **Name:** Payal Sharma
#
# ### Objective
#
# Design a complete Machine Learning workflow by thinking like a production Data Scientist. The workflow includes business understanding, data collection, preprocessing, model development, evaluation, deployment planning, monitoring, and ethical considerations.

# %% [markdown]
# ## Step 1: Business Understanding
#
# **Business Problem:**
# A telecom company wants to identify customers who are likely to leave (customer churn).
#
# **Goal:**
# Predict customer churn so the company can take preventive actions and improve customer retention.

# %% [markdown]
# ## Step 2: Import Required Library

# %%
import pandas as pd

# %% [markdown]
# ## Step 3: Load the Dataset

# %%
df = pd.read_csv("customer_churn.csv")
df.head()
# Out:
#    Customer_ID  Age  Monthly_Charges  Tenure Contract_Type Churn
# 0          101   22              499      12       Monthly    No
# 1          102   35              899      36        Yearly    No
# 2          103   28              699      18       Monthly   Yes
# 3          104   45              999      48        Yearly    No
# 4          105   30              599      24       Monthly   Yes

# %% [markdown]
# ## Step 4: Explore the Dataset

# %%
print("Dataset Shape:", df.shape)

print("\nDataset Information:")
df.info()

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (10, 6)
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      10 non-null     int64
#  1   Age              10 non-null     int64
#  2   Monthly_Charges  10 non-null     int64
#  3   Tenure           10 non-null     int64
#  4   Contract_Type    10 non-null     str
#  5   Churn            10 non-null     str
# dtypes: int64(4), str(2)
# memory usage: 612.0 bytes
#
# Missing Values:
# Customer_ID        0
# Age                0
# Monthly_Charges    0
# Tenure             0
# Contract_Type      0
# Churn              0
# dtype: int64

# %% [markdown]
# ## Step 5: Data Preparation

# %%
print("Checking Duplicate Records:", df.duplicated().sum())

print("Checking Target Labels:")
print(df["Churn"].value_counts())
# Out:
# Checking Duplicate Records: 0
# Checking Target Labels:
# Churn
# No     5
# Yes    5
# Name: count, dtype: int64

# %% [markdown]
# ## Step 6: Model Selection

# %%
print("Selected Model: Logistic Regression")

print("Reason:")
print("- Suitable for classification")
print("- Easy to interpret")
print("- Works well for binary prediction")
# Out:
# Selected Model: Logistic Regression
# Reason:
# - Suitable for classification
# - Easy to interpret
# - Works well for binary prediction

# %% [markdown]
# ## Step 7: Model Evaluation

# %%
print("Evaluation Metrics")

metrics = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1 Score"
]

for metric in metrics:
    print("✔", metric)
# Out:
# Evaluation Metrics
# ✔ Accuracy
# ✔ Precision
# ✔ Recall
# ✔ F1 Score

# %% [markdown]
# ## Step 8: Deployment Planning

# %%
deployment_steps = [
    "Deploy model as a web API",
    "Connect with customer database",
    "Predict churn for new customers",
    "Display predictions on dashboard"
]

for step in deployment_steps:
    print("➡", step)
# Out:
# ➡ Deploy model as a web API
# ➡ Connect with customer database
# ➡ Predict churn for new customers
# ➡ Display predictions on dashboard

# %% [markdown]
# ## Step 9: Monitoring & Maintenance

# %%
monitoring = [
    "Monitor model accuracy",
    "Update model with new data",
    "Detect performance degradation",
    "Retrain model periodically"
]

for item in monitoring:
    print("✔", item)
# Out:
# ✔ Monitor model accuracy
# ✔ Update model with new data
# ✔ Detect performance degradation
# ✔ Retrain model periodically

# %% [markdown]
# ## Step 10: Ethics & Responsible AI

# %%
ethics = [
    "Protect customer privacy",
    "Avoid biased predictions",
    "Ensure transparency",
    "Maintain data security",
    "Keep human oversight"
]

for item in ethics:
    print("⚖", item)
# Out:
# ⚖ Protect customer privacy
# ⚖ Avoid biased predictions
# ⚖ Ensure transparency
# ⚖ Maintain data security
# ⚖ Keep human oversight

# %% [markdown]
# ## Complete Machine Learning Workflow

# %%
workflow = [
    "Business Understanding",
    "Data Collection",
    "Data Preparation",
    "Feature Selection",
    "Model Training",
    "Model Evaluation",
    "Deployment",
    "Monitoring",
    "Ethics"
]

for i, step in enumerate(workflow, start=1):
    print(f"{i}. {step}")
# Out:
# 1. Business Understanding
# 2. Data Collection
# 3. Data Preparation
# 4. Feature Selection
# 5. Model Training
# 6. Model Evaluation
# 7. Deployment
# 8. Monitoring
# 9. Ethics

# %% [markdown]
# ## Conclusion
#
# This project demonstrates the complete Machine Learning lifecycle followed by production Data Scientists. It emphasizes that a successful ML solution involves much more than training a model—it requires careful planning, evaluation, deployment, monitoring, and responsible AI practices.
