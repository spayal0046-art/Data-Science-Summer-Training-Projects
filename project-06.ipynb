# %% [markdown]
# # Project 6: ML Feasibility Assessment
#
# ## 45-Day Summer Training
# ### LinuxWorld Informatics Pvt. Ltd.
#
# **Name:** Payal Sharma
#
# ### Objective
#
# To evaluate whether Machine Learning is suitable for solving a business problem by analyzing the dataset, identifying the appropriate ML approach, and justifying the feasibility.

# %% [markdown]
# ## Import Required Library

# %%
import pandas as pd

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv("customer_churn.csv")
df
# Out:
#    Customer_ID  Age  Monthly_Charges Contract_Type  Tenure Churn
# 0          101   22              499       Monthly      12    No
# 1          102   35              899        Yearly      36    No
# 2          103   28              699       Monthly      18   Yes
# 3          104   45              999        Yearly      48    No
# 4          105   30              599       Monthly      24   Yes
# 5          106   27              650       Monthly      10   Yes
# 6          107   40              950        Yearly      50    No
# 7          108   24              450       Monthly       8   Yes
# 8          109   38              850        Yearly      40    No
# 9          110   29              700       Monthly      20   Yes

# %% [markdown]
# ## Inspect Dataset Structure

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      10 non-null     int64
#  1   Age              10 non-null     int64
#  2   Monthly_Charges  10 non-null     int64
#  3   Contract_Type    10 non-null     str
#  4   Tenure           10 non-null     int64
#  5   Churn            10 non-null     str
# dtypes: int64(4), str(2)
# memory usage: 612.0 bytes

# %% [markdown]
# ## Check Dataset Size

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (10, 6)

# %% [markdown]
# ## Check Target Labels

# %%
print(df["Churn"].value_counts())
# Out:
# Churn
# No     5
# Yes    5
# Name: count, dtype: int64

# %% [markdown]
# ## Is Machine Learning Suitable?

# %%
print("Dataset contains historical customer data.")
print("The target variable (Churn) is available.")
print("Patterns can be learned from previous records.")
print("Machine Learning is suitable for this problem.")
# Out:
# Dataset contains historical customer data.
# The target variable (Churn) is available.
# Patterns can be learned from previous records.
# Machine Learning is suitable for this problem.

# %% [markdown]
# ## Suitable Machine Learning Approach

# %%
print("Recommended ML Approach: Supervised Learning")
print("Problem Type: Classification")
# Out:
# Recommended ML Approach: Supervised Learning
# Problem Type: Classification

# %% [markdown]
# ## Feasibility Assessment

# %%
print("Dataset Size:", df.shape[0], "records")
print("Dataset Structure: Structured (Tabular Data)")
print("Labels Available: Yes (Churn)")
print("\nConclusion: The dataset is suitable for building a Machine Learning Classification model.")
# Out:
# Dataset Size: 10 records
# Dataset Structure: Structured (Tabular Data)
# Labels Available: Yes (Churn)
#
# Conclusion: The dataset is suitable for building a Machine Learning Classification model.

# %% [markdown]
# ## Justification for Feasibility and Rejection

# %%
print("Feasibility:")
print("- Historical data is available.")
print("- Data is structured.")
print("- Labels are present.")
print("- Suitable for supervised learning.")

print("\nRejection Conditions:")
print("- If labels were missing.")
print("- If the dataset were too small.")
print("- If the data quality were poor.")
print("- If there were no patterns to learn.")
# Out:
# Feasibility:
# - Historical data is available.
# - Data is structured.
# - Labels are present.
# - Suitable for supervised learning.
#
# Rejection Conditions:
# - If labels were missing.
# - If the dataset were too small.
# - If the data quality were poor.
# - If there were no patterns to learn.

# %% [markdown]
# ## Conclusion
#
# The dataset was evaluated for Machine Learning feasibility by checking its size, structure, and target labels. Since the data is structured, labeled, and contains historical information, a supervised classification model can be developed to predict customer churn.
